# %%
# !pip install -q tabula-py

# %%
from tabula import read_pdf

# %%
df_alimentos = read_pdf("alimentos-miriam.pdf", pages='89')

# %%
df_alimentos[0]
# Out:
#        6.1 CEREALES Y DERIVADOS           Unnamed: 0           Unnamed: 1  \
# 0        6.1.1 Maíz y derivados                  NaN                  NaN
# 1                           NaN            CYD-MYD-1            CYD-MYD-2
# 2        Componente alimentario         Maíz\rblanco       Maíz\ramarillo
# 3                     Nutriente              Tagname               Unidad
# 4         Elementos principales                  NaN                  NaN
# 5                       Energía                ENERC                 kcal
# 6                           NaN                  NaN                   kJ
# 7                       Humedad                WATER                    %
# 8               Fibra dietética                FIBTG                    g
# 9                 Hidratos de C               CHOCDF                    g
# 10                    Proteínas               PROCNT                    g
# 11                  Lípidos tot                  FAT                    g
# ...

# %%
hola='test %r'

# %%
print('test %r'%s)
# Out:
# test 'test %r'

# %%
hola
# Out:
# 'test %r'
